# %% [markdown]
# # Coding Exercises (Part 12)

# %% [markdown]
# ## Financial Data: Essential Workflows

# %% [markdown]
# ### Exercise 12: Financial Time Series

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Option 1: Self_guided

# %% [markdown]
# Import the us stocks dataset (__us_stocks.csv__) and select the Adjusted Close (__Adj Close__) for all six stocks from __31-12-2015__ (incl.) until __31-12-2018__ (incl.). Save the DataFrame in the variable __stocks__ and work through the next questions with this DataFrame!

# %% [markdown]
# - __Visualize__ the Adjusted Close of the six stocks __over time__!

# %%
#run the cell!
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")

tickers = ["AAPL", "ADBE", "AMZN", "ARKG", "ARKK", "BOMN", "BRK-B", "CRM", "FB", "FSLY", "JPM", "MCD", "MELI", "MRNA", "MSFT", "MSTR", "OKTA", "SQ", "TFC", "TSLA", "TTD", "SHOP", "TWLO", "ZM"]
stocks = yf.download(tickers, start="2018-01-01", end="2021-03-08")
# Out:
# [*********************100%***********************]  24 of 24 completed

# %%
stocks.head()
# Out:
#             Adj Close                                                 \
#                  AAPL        ADBE         AMZN       ARKG       ARKK
# Date
# 2018-01-02  41.380238  177.699997  1189.010010  23.955498  36.654652
# 2018-01-03  41.373032  181.039993  1204.199951  24.125462  36.806664
# 2018-01-04  41.565216  183.220001  1209.589966  24.323751  36.930176
# 2018-01-05  42.038452  185.339996  1229.140015  24.408735  37.528736
# 2018-01-08  41.882305  185.039993  1246.869995  23.785532  37.272209
#
#                                                                 ...    Volume  \
#                  BOMN       BRK-B         CRM          FB FSLY  ...      MSFT
# Date                                                            ...
# 2018-01-02  29.389999  197.220001  104.410004  181.419998  NaN  ...  22483800
# 2018-01-03  27.480000  199.789993  105.290001  184.669998  NaN  ...  26061400
# 2018-01-04  26.090000  200.690002  106.680000  184.330002  NaN  ...  21912000
# 2018-01-05  24.320000  201.419998  108.099998  186.850006  NaN  ...  23407100
# 2018-01-08  23.700001  202.740005  108.860001  188.279999  NaN  ...  22113000
#
#                                                                           \
#              MSTR     OKTA     SHOP        SQ      TFC      TSLA     TTD
# Date
# 2018-01-02  55500  1635300  1394500  11240500  2503400  21761000  690200
# 2018-01-03  71900  2404300  1162700  11617900  3410700  22607500  821800
# 2018-01-04  76500   948800  1161000  20469800  3809900  49731500  564700
# 2018-01-05  51200  1553600   771000  31102000  3345000  22956000  584100
# 2018-01-08  56700  1287800   748700  26626100  3524300  49297000  572700
#
#
#                TWLO  ZM
# Date
# 2018-01-02  1942400 NaN
# 2018-01-03  1632000 NaN
# 2018-01-04  1260800 NaN
# 2018-01-05  1023800 NaN
# 2018-01-08  1533800 NaN
#
# [5 rows x 144 columns]

# %%
stocks.to_csv("adam_dana.csv")

# %%
stocks = pd.read_csv("adam_dana.csv", header= [0, 1], index_col=[0], parse_dates=[0])

# %%
stocks
# Out:
#              Adj Close                                                  \
#                   AAPL        ADBE         AMZN       ARKG        ARKK
# Date
# 2018-01-02   41.380238  177.699997  1189.010010  23.955498   36.654652
# 2018-01-03   41.373032  181.039993  1204.199951  24.125462   36.806664
# 2018-01-04   41.565216  183.220001  1209.589966  24.323751   36.930176
# 2018-01-05   42.038452  185.339996  1229.140015  24.408735   37.528736
# 2018-01-08   41.882305  185.039993  1246.869995  23.785532   37.272209
# ...                ...         ...          ...        ...         ...
# 2021-03-01  127.790001  469.570007  3146.139893  97.790001  136.699997
# 2021-03-02  125.120003  466.589996  3094.530029  95.959999  133.509995
# 2021-03-03  122.059998  448.450012  3005.000000  90.330002  125.110001
# 2021-03-04  120.129997  439.059998  2977.570068  85.129997  118.430000
# 2021-03-05  121.419998  440.829987  3000.459961  85.139999  117.070000
#
#                                                                       ...  \
#                  BOMN       BRK-B         CRM          FB       FSLY  ...
# Date                                                                  ...
# 2018-01-02  29.389999  197.220001  104.410004  181.419998        NaN  ...
# 2018-01-03  27.480000  199.789993  105.290001  184.669998        NaN  ...
# 2018-01-04  26.090000  200.690002  106.680000  184.330002        NaN  ...
# 2018-01-05  24.320000  201.419998  108.099998  186.850006        NaN  ...
# 2018-01-08  23.700001  202.740005  108.860001  188.279999        NaN  ...
# ...               ...         ...         ...         ...        ...  ...
# 2021-03-01  46.250000  249.210007  217.539993  264.910004  77.250000  ...
# 2021-03-02  44.869999  249.220001  213.470001  259.000000  70.900002  ...
# 2021-03-03  43.310001  251.550003  206.000000  255.410004  68.010002  ...
# 2021-03-04  39.770000  245.479996  205.330002  257.640015  65.489998  ...
# 2021-03-05  38.680000  253.149994  210.759995  264.279999  64.839996  ...
#
#               Volume                                                          \
#                 MSFT     MSTR     OKTA     SHOP        SQ      TFC      TSLA
# Date
# 2018-01-02  22483800    55500  1635300  1394500  11240500  2503400  21761000
# 2018-01-03  26061400    71900  2404300  1162700  11617900  3410700  22607500
# 2018-01-04  21912000    76500   948800  1161000  20469800  3809900  49731500
# 2018-01-05  23407100    51200  1553600   771000  31102000  3345000  22956000
# 2018-01-08  22113000    56700  1287800   748700  26626100  3524300  49297000
# ...              ...      ...      ...      ...       ...      ...       ...
# 2021-03-01  25324000   760800  1160300  1269800   8834000  4751000  27009700
# 2021-03-02  22785500   642100  1392400  1274300  17317100  5087500  23617600
# 2021-03-03  33950400   768600  3278300  1149500  12103000  6178900  29957200
# 2021-03-04  44584200  1211100  9006200  2740900  18423900  5940700  65448500
# 2021-03-05  41842100  1353300  6895400  3941200  24750600  6149000  89300300
#
#
#                 TTD     TWLO          ZM
# Date
# 2018-01-02   690200  1942400         NaN
# 2018-01-03   821800  1632000         NaN
# 2018-01-04   564700  1260800         NaN
# 2018-01-05   584100  1023800         NaN
# 2018-01-08   572700  1533800         NaN
# ...             ...      ...         ...
# 2021-03-01   512500  2164700   9947400.0
# 2021-03-02   462700  1881100  18058000.0
# 2021-03-03  1862200  2829800  15485200.0
# 2021-03-04  2127200  4200400  10297700.0
# 2021-03-05  3026900  4228300   8248600.0
#
# [799 rows x 144 columns]

# %% [markdown]
# - __Visualize__ the __normalized__ Adjusted Close of the six stocks __over time__, each starting at a __Base Value of 100__!

# %%
normalized = stocks.loc[:, "Close"].copy()

# %%
normalized = normalized.div(normalized.iloc[0]).mul(100)

# %%
normalized = normalized.fillna(100)

# %%
normalized
# Out:
#                   AAPL        ADBE        AMZN        ARKG        ARKK  \
# Date
# 2018-01-02  100.000000  100.000000  100.000000  100.000000  100.000000
# 2018-01-03   99.982585  101.879570  101.277528  100.709493  100.414722
# 2018-01-04  100.447001  103.106361  101.730848  101.537246  100.751677
# 2018-01-05  101.590622  104.299381  103.375077  101.891997  102.384650
# 2018-01-08  101.213289  104.130555  104.866232   99.290499  101.684805
# ...                ...         ...         ...         ...         ...
# 2021-03-01  296.737501  264.248742  264.601632  385.455253  354.328643
# 2021-03-02  290.537575  262.571753  260.261058  378.242002  346.060104
# 2021-03-03  283.432025  252.363545  252.731262  356.050449  324.287182
# 2021-03-04  278.950426  247.079350  250.424306  335.553782  306.972511
# 2021-03-05  281.945900  248.075405  252.349428  335.593207  303.447367
#
#                   BOMN       BRK-B         CRM          FB   FSLY  ...  \
# Date                                                               ...
# 2018-01-02  100.000000  100.000000  100.000000  100.000000  100.0  ...
# 2018-01-03   93.501191  101.303109  100.842828  101.791423  100.0  ...
# 2018-01-04   88.771693  101.759457  102.174118  101.604015  100.0  ...
# 2018-01-05   82.749235  102.129600  103.534139  102.993059  100.0  ...
# 2018-01-08   80.639678  102.798907  104.262041  103.781281  100.0  ...
# ...                ...         ...         ...         ...    ...  ...
# 2021-03-01  157.366454  126.361426  208.351677  146.020288  100.0  ...
# 2021-03-02  152.670976  126.366494  204.453590  142.762652  100.0  ...
# 2021-03-03  147.363056  127.547917  197.299102  140.783820  100.0  ...
# 2021-03-04  135.318140  124.470132  196.657403  142.013018  100.0  ...
# 2021-03-05  131.609395  128.359189  201.858047  145.673025  100.0  ...
#
#                   MSFT        MSTR         OKTA         SHOP          SQ  \
# Date
# 2018-01-02  100.000000  100.000000   100.000000   100.000000  100.000000
# 2018-01-03  100.465389  100.440062   100.113381   102.142385  103.151792
# 2018-01-04  101.349626  102.473440   100.415724   104.227888  105.335915
# 2018-01-05  102.606173  102.435502   100.302350   104.825106  113.740673
# 2018-01-08  102.710881  103.649467    99.735451   106.502987  112.690076
# ...                ...         ...          ...          ...         ...
# 2021-03-01  275.671915  593.657044  1019.690124  1241.766962  666.298071
# 2021-03-02  272.100062  567.905905   979.062761  1240.932871  697.262952
# 2021-03-03  264.758587  555.060691   911.640248  1156.792183  647.497951
# 2021-03-04  263.792907  489.878572   854.950903  1089.619836  603.843004
# 2021-03-05  269.459004  470.591787   816.175413  1072.149050  598.396498
#
#                    TFC         TSLA          TTD         TWLO     ZM
# Date
# 2018-01-02  100.000000   100.000000   100.000000   100.000000  100.0
# 2018-01-03  101.081733    98.976692   103.232062   102.350598  100.0
# 2018-01-04  102.303689    98.156174   102.671842   102.310757  100.0
# 2018-01-05  102.624202    98.767665   104.180131   102.629481  100.0
# 2018-01-08  103.165068   104.954286   103.145872   104.262947  100.0
# ...                ...          ...          ...          ...    ...
# 2021-03-01  117.808501  1120.690670  1793.449751  1656.493994  100.0
# 2021-03-02  116.706732  1070.788963  1719.263038  1572.191192  100.0
# 2021-03-03  117.167476  1018.937359  1499.525953  1452.270850  100.0
# 2021-03-04  114.943917   969.394402  1379.357844  1378.685189  100.0
# 2021-03-05  117.628212   932.751983  1409.545324  1343.744995  100.0
#
# [799 rows x 24 columns]

# %%
normalized.plot(kind="line", figsize=(15,10), fontsize=13)
plt.legend(fontsize=12, loc="upper left")

# %% [markdown]
# - Calculate __monthly returns__ for all six stocks and create a new __returns__ DataFrame!

# %%
returns = stocks.pct_change().dropna()
returns
# Out:
#            Adj Close                                                    \
#                 AAPL      ADBE      AMZN      ARKG      ARKK      BOMN
# Date
# 2019-05-20 -0.031270 -0.015723 -0.005367 -0.013531 -0.023430 -0.005976
# 2019-05-21  0.019171  0.009512 -0.000780  0.028739  0.022595 -0.002004
# 2019-05-22 -0.020472  0.013486  0.001163 -0.011111 -0.015262  0.002410
# 2019-05-23 -0.017070 -0.026861 -0.023768 -0.025682 -0.027527 -0.003606
# 2019-05-24 -0.003841  0.001896  0.004296  0.005931  0.002379 -0.003217
# ...              ...       ...       ...       ...       ...       ...
# 2021-03-01  0.053851  0.021537  0.017204  0.045770  0.048635  0.101715
# 2021-03-02 -0.020894 -0.006346 -0.016404 -0.018714 -0.023336 -0.029838
# 2021-03-03 -0.024457 -0.038878 -0.028932 -0.058670 -0.062917 -0.034767
# 2021-03-04 -0.015812 -0.020939 -0.009128 -0.057567 -0.053393 -0.081736
# 2021-03-05  0.010738  0.004031  0.007687  0.000117 -0.011484 -0.027408
#
#                                                     ...    Volume            \
#                BRK-B       CRM        FB      FSLY  ...      MSFT      MSTR
# Date                                                ...
# 2019-05-20 -0.002657  0.009122 -0.013923  0.010838  ... -0.080076 -0.189845
# 2019-05-21  0.003108 -0.001282  0.011493 -0.065567  ... -0.354901  0.226158
# 2019-05-22 -0.003737  0.011940  0.002705 -0.006178  ...  0.006748 -0.393333
# 2019-05-23 -0.006417 -0.024930 -0.024013 -0.000888  ...  0.533063  0.474359
# 2019-05-24  0.001937  0.005205  0.001050 -0.044444  ... -0.401647 -0.052174
# ...              ...       ...       ...       ...  ...       ...       ...
# 2021-03-01  0.036173  0.004804  0.028298  0.049878  ... -0.330251 -0.353061
# 2021-03-02  0.000040 -0.018709 -0.022309 -0.082201  ... -0.100241 -0.156020
# 2021-03-03  0.009349 -0.034993 -0.013861 -0.040762  ...  0.490000  0.197010
# 2021-03-04 -0.024130 -0.003252  0.008731 -0.037053  ...  0.313216  0.575722
# 2021-03-05  0.031245  0.026445  0.025772 -0.009925  ... -0.061504  0.117414
#
#                                                                         \
#                 OKTA      SHOP        SQ       TFC      TSLA       TTD
# Date
# 2019-05-20 -0.603853  0.113304 -0.022320 -0.421797  0.154020 -0.071538
# 2019-05-21 -0.232924 -0.401756 -0.151360 -0.206456 -0.122882  0.281942
# 2019-05-22  0.026972  0.127522  0.174847  0.435879  0.037842 -0.288961
# 2019-05-23  0.561130  0.222284  0.410659  0.071039  0.420755  0.171823
# 2019-05-24 -0.280782 -0.239757 -0.153581 -0.262052 -0.467490 -0.178150
# ...              ...       ...       ...       ...       ...       ...
# 2021-03-01 -0.126083 -0.039413 -0.407050 -0.561639 -0.341408 -0.433952
# 2021-03-02  0.200034  0.003544  0.960278  0.070827 -0.125588 -0.097171
# 2021-03-03  1.354424 -0.097936 -0.301095  0.214526  0.268427  3.024638
# 2021-03-04  1.747217  1.384428  0.522259 -0.038551  1.184734  0.142305
# 2021-03-05 -0.234372  0.437922  0.343396  0.035063  0.364436  0.422950
#
#
#                 TWLO        ZM
# Date
# 2019-05-20 -0.294742  0.065156
# 2019-05-21 -0.100988 -0.297480
# 2019-05-22 -0.212119 -0.380280
# 2019-05-23  0.327253  0.789025
# 2019-05-24 -0.028115  0.031793
# ...              ...       ...
# 2021-03-01 -0.273688  1.115388
# 2021-03-02 -0.131011  0.815349
# 2021-03-03  0.504333 -0.142474
# 2021-03-04  0.484345 -0.334997
# 2021-03-05  0.006642 -0.198986
#
# [453 rows x 144 columns]

# %%
#returns = returns.loc[:, "Close"].copy()

# %%
returns.plot(kind="hist", figsize=(12,8), bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
daily_mean_return = returns.mean()

# %%
daily_mean_return

monthly_mean_return = returns.mean() * 12
monthly_mean_return
# Out:
# AAPL     0.028604
# ADBE     0.015759
# AMZN     0.014991
# ARKG     0.031497
# ARKK     0.030214
# BOMN     0.017048
# BRK-B    0.007653
# CRM      0.012546
# FB       0.012958
# FSLY     0.047654
# JPM      0.012537
# MCD      0.003488
# MELI     0.031347
# MRNA     0.063158
# MSFT     0.018694
# MSTR     0.051490
# OKTA     0.023175
# SHOP     0.046180
# SQ       0.041045
# TFC      0.011893
# TSLA     0.083942
# TTD      0.042661
# TWLO     0.031513
# ZM       0.047811
# dtype: float64

# %% [markdown]
# - Calculate the __annualized mean return__ and the __annualized standard deviation__ of returns for all six stocks!

# %%
summary = returns.describe().T.loc[:, ["mean", "std"]]

# %%
summary
# Out:
#            mean       std
# AAPL   0.002384  0.024434
# ADBE   0.001313  0.024947
# AMZN   0.001249  0.020239
# ARKG   0.002625  0.028019
# ARKK   0.002518  0.026410
# BOMN   0.001421  0.030694
# BRK-B  0.000638  0.017510
# CRM    0.001045  0.027140
# FB     0.001080  0.024287
# FSLY   0.003971  0.060134
# JPM    0.001045  0.026980
# MCD    0.000291  0.020139
# MELI   0.002612  0.032801
# MRNA   0.005263  0.053770
# MSFT   0.001558  0.022320
# MSTR   0.004291  0.044146
# OKTA   0.001931  0.030340
# SHOP   0.003848  0.037660
# SQ     0.003420  0.038861
# TFC    0.000991  0.032804
# TSLA   0.006995  0.047489
# TTD    0.003555  0.042894
# TWLO   0.002626  0.038140
# ZM     0.003984  0.047039

# %%
summary["mean_annual"] = summary["mean"]*252
summary["std_annual"] = summary["std"] *np.sqrt(252)

# %%
summary
# Out:
#            mean       std  mean_annual  std_annual
# AAPL   0.002384  0.024434     0.600691    0.387870
# ADBE   0.001313  0.024947     0.330942    0.396022
# AMZN   0.001249  0.020239     0.314815    0.321289
# ARKG   0.002625  0.028019     0.661441    0.444787
# ARKK   0.002518  0.026410     0.634497    0.419242
# BOMN   0.001421  0.030694     0.358016    0.487245
# BRK-B  0.000638  0.017510     0.160706    0.277967
# CRM    0.001045  0.027140     0.263457    0.430834
# FB     0.001080  0.024287     0.272122    0.385537
# FSLY   0.003971  0.060134     1.000738    0.954593
# JPM    0.001045  0.026980     0.263281    0.428298
# MCD    0.000291  0.020139     0.073239    0.319690
# MELI   0.002612  0.032801     0.658283    0.520700
# MRNA   0.005263  0.053770     1.326328    0.853576
# MSFT   0.001558  0.022320     0.392583    0.354324
# MSTR   0.004291  0.044146     1.081282    0.700792
# OKTA   0.001931  0.030340     0.486671    0.481635
# SHOP   0.003848  0.037660     0.969788    0.597835
# SQ     0.003420  0.038861     0.861948    0.616901
# TFC    0.000991  0.032804     0.249753    0.520744
# TSLA   0.006995  0.047489     1.762780    0.753863
# TTD    0.003555  0.042894     0.895874    0.680928
# TWLO   0.002626  0.038140     0.661780    0.605458
# ZM     0.003984  0.047039     1.004035    0.746723

# %% [markdown]
# - __Visualize risk/return__ of all six stocks in a (total) risk / return framework. (annualized std on the x-axis, annualized mean returns on the y-axis). <br>
# Identify the __best performing__ stock and the __worst performing__ stock (in terms of __risk / return__)

# %%
summary.plot.scatter(x = "std_annual", y="mean_annual", figsize=(12,8), s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std_annual"]+0.002, summary.loc[i, "mean_annual"]+0.002), size=15)
plt.xlabel("ann. Risk(std)", fontsize=15)
plt.ylabel("ann. Return", fontsize=15)
plt.title("Risk/Return", fontsize=20)
plt.show()

# %% [markdown]
# - __Visualize__ the __correlation matrix__ of monthly returns with a __Seaborn Heatmap__. Which stocks-pair shows the __highest (positive) correlation__ of monthly returns?

# %%
import seaborn as sns
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(returns.corr(), cmap="Reds", annot=False, annot_kws={"size": 12}, vmax=0.6)
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Ticker Symbols__:
# - AXP : American Express
# - FB : Facebook
# - INTC : Intel
# - MCD : McDonalds
# - PG : Procter & Gamble
# - WMT: Walmart

# %% [markdown]
# ------------------------

# %% [markdown]
# ## Option 2: Guided and Instructed

# %% [markdown]
# # STOP HERE, IF YOU WANT TO DO THE EXERCISE ON YOUR OWN!

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
#run the cell!
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %% [markdown]
# 105. __Import__ daily stock price data (__us_stocks.csv__) and __inspect__! Handle the __MultiIndex__! __Fill in the gaps__!

# %%
tickers = ["AAPL", "ADBE", "AMZN", "ARKG", "ARKK", "BOMN", "BRK-B", "CRM", "FB", "FSLY", "JPM", "MCD", "MELI", "MRNA", "MSFT", "MSTR", "OKTA", "SQ", "TFC", "TSLA", "TTD", "SHOP", "TWLO", "ZM"]
stocks = yf.download(tickers, start="2018-01-01", end="2020-03-08")

# %%
# run the cell!
stocks.head()
# Out:
#                      Adj Close                                                 \
#                           AAPL        ADBE         AMZN       ARKG       ARKK
# Date
# 2018-01-02 00:00:00  41.380238  177.699997  1189.010010  23.955498  36.654652
# 2018-01-03 00:00:00  41.373032  181.039993  1204.199951  24.125462  36.806664
# 2018-01-04 00:00:00  41.565216  183.220001  1209.589966  24.323751  36.930176
# 2018-01-05 00:00:00  42.038452  185.339996  1229.140015  24.408735  37.528736
# 2018-01-08 00:00:00  41.882305  185.039993  1246.869995  23.785532  37.272209
#
#                                                                    ... Volume  \
#                           BOMN BRK.B         CRM          FB FSLY  ...   MSTR
# Date                                                               ...
# 2018-01-02 00:00:00  29.389999   NaN  104.410004  181.419998  NaN  ...  55500
# 2018-01-03 00:00:00  27.480000   NaN  105.290001  184.669998  NaN  ...  71900
# 2018-01-04 00:00:00  26.090000   NaN  106.680000  184.330002  NaN  ...  76500
# 2018-01-05 00:00:00  24.320000   NaN  108.099998  186.850006  NaN  ...  51200
# 2018-01-08 00:00:00  23.700001   NaN  108.860001  188.279999  NaN  ...  56700
#
#                                                                          \
#                         OKTA OPEN     SHOP        SQ      TFC      TSLA
# Date
# 2018-01-02 00:00:00  1635300  NaN  1394500  11240500  2503400  21761000
# 2018-01-03 00:00:00  2404300  NaN  1162700  11617900  3410700  22607500
# 2018-01-04 00:00:00   948800  NaN  1161000  20469800  3809900  49731500
# 2018-01-05 00:00:00  1553600  NaN   771000  31102000  3345000  22956000
# 2018-01-08 00:00:00  1287800  NaN   748700  26626100  3524300  49297000
#
#
#                         TTD     TWLO  ZM
# Date
# 2018-01-02 00:00:00  690200  1942400 NaN
# 2018-01-03 00:00:00  821800  1632000 NaN
# 2018-01-04 00:00:00  564700  1260800 NaN
# 2018-01-05 00:00:00  584100  1023800 NaN
# 2018-01-08 00:00:00  572700  1533800 NaN
#
# [5 rows x 150 columns]

# %% [markdown]
# Ticker Symbols:
# - AXP : American Express
# - FB : Facebook
# - INTC : Intel
# - MCD : McDonalds
# - PG : Procter & Gamble
# - WMT: Walmart

# %% [markdown]
# 106. __Select__ the Adjusted Close (__Adj Close__) for all six stocks from __31-12-2015__ (incl.) until __31-12-2018__ (incl.)! __Overwrite__ stocks! <br>
# __How many Timestamps__ / Days are in the DataFrame now?

# %%
# run the cell!
stocks.head()

# %%
# run the cell!
stocks.info()

# %% [markdown]
# We have ... 754 Days.

# %% [markdown]
# 107. __Plot__ stocks (figsize (12, 8)!

# %% [markdown]
# 108. __Bring__ the six stocks to the __same Base Value__ (100) and __plot__ again! __Fill in the gaps!__

# %%
stocks.---(stocks.iloc[0]).---(figsize = (12,8))
plt.show()

# %% [markdown]
# Still hard to compare performance, right?

# %% [markdown]
# 109. __Resample__ stocks to __monthly__ frequency (__last__ trading price of each month, index should show last calender day)!<br> __Save__ the resampled Dataframe in the variable __stocks_m__!

# %%
# run the cell!
stocks_m.head()

# %% [markdown]
# 110. Calculate __monthly returns__ and __save__ the result in the variable __ret__! (drop NaN Values!)

# %%
#run the cell!
ret

# %% [markdown]
# 111. Calculate __mean__ and  __standard deviation__ of monthly returns! __Save__ the result in the variable __summary__!<br>
# __Fill in the gaps!__

# %%
summary = ret.agg([---, ---]).T

# %%
#run the cell!
summary

# %% [markdown]
# 112. __Annualize__ mean and standard deviation of returns! __Fill in the gaps!__

# %%
summary["mean"] = summary["mean"]*---
summary["std"] = summary["std"]*---(---)

# %%
#run the cell!
summary

# %% [markdown]
# 113. __Plot__ and __compare__ the performance of the six stocks in a __(total) risk / return__ framework! __Fill in the gaps__! <br>
# Can you identify the __best performing__ stock and the __worst performing__ stock (in terms of __risk / return__)?

# %%
summary.plot(kind = "---", x = "---", y = "---", figsize = (12, 8), s = 50, fontsize = 15, xlim = (0.1, 0.3), ylim = (0, 0.25))
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "std"]+0.002, summary.loc[i, "mean"]+0.002), size = 15)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# In a (total) risk / return framework, McDonalds (most likely) showed the best performance (upper left) and facebook the worst performance (lower right)!

# %% [markdown]
# 114. Prepare the __correlation matrix__ of monthly returns. Which stocks-pair shows the __highest (positive) correlation__ of monthly returns?

# %% [markdown]
# The highest positive correlation of returns is between ... Walmart and McDonalds.

# %% [markdown]
# 115. __Visualize__ the correlation matrix with a __Seaborn Heatmap__! __Fill in the gaps!__

# %%
# run the cell!
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.0)
sns.---(---, cmap = "RdYlGn", annot = True, vmin = -0.5, vmax = 0.6, center = 0)
plt.show()

# %% [markdown]
# # Well Done!

# %% [markdown]
# -------------------

# %% [markdown]
# # Hints (Spoiler!)

# %% [markdown]
# 105. The first two rows (index pos. 0 & 1) form the MultiIndex. The Column with Datetime information is at index pos. 0.

# %% [markdown]
# 106. stocks = stocks.loc[---:---, ---]

# %% [markdown]
# 107. plot() method

# %% [markdown]
# 108. div() method, plot() method

# %% [markdown]
# 109. resample() method, last() method, use "M"

# %% [markdown]
# 110. pct_change() method, dropna() method

# %% [markdown]
# 111. agg() method, "mean" and "std"

# %% [markdown]
# 112. *12 and *np.sqrt(12)

# %% [markdown]
# 113. scatterplot, std and mean

# %% [markdown]
# 114. corr() method

# %% [markdown]
# 115. heatmap, ret.corr()
