# %% [markdown]
# ### Data Import Visualization and Normalization of Indexes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
plt.style.use("seaborn")

# %%
stocks = yf.download(["AMZN", "BA", "DIS", "IBM", "KO", "MSFT"], start="2014-01-01", end="2018-12-31")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks.to_csv("data/index_stocks.csv")

# %%
stocks = pd.read_csv("data/index_stocks.csv", header=[0,1], index_col=[0], parse_dates=[0]).Close

# %%
stocks
# Out:
#                    AMZN          BA         DIS         IBM         KO  \
# Date
# 2014-01-02   397.970001  136.669998   76.269997  185.529999  40.660000
# 2014-01-03   396.440002  137.619995   76.110001  186.639999  40.459999
# 2014-01-06   393.630005  138.410004   75.820000  186.000000  40.270000
# 2014-01-07   398.029999  140.509995   76.339996  189.710007  40.389999
# 2014-01-08   401.920013  140.820007   75.220001  187.970001  39.939999
# ...                 ...         ...         ...         ...        ...
# 2018-12-21  1377.449951  304.549988  104.220001  110.940002  47.570000
# 2018-12-24  1343.959961  294.160004  100.349998  107.570000  45.959999
# 2018-12-26  1470.900024  313.929993  105.830002  111.389999  46.939999
# 2018-12-27  1461.640015  317.140015  106.519997  113.779999  47.529999
# 2018-12-28  1478.020020  316.380005  107.300003  113.029999  47.200001
#
#                   MSFT
# Date
# 2014-01-02   37.160000
# 2014-01-03   36.910000
# 2014-01-06   36.130001
# 2014-01-07   36.410000
# 2014-01-08   35.759998
# ...                ...
# 2018-12-21   98.230003
# 2018-12-24   94.129997
# 2018-12-26  100.559998
# 2018-12-27  101.180000
# 2018-12-28  100.389999
#
# [1257 rows x 6 columns]

# %%
stocks.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)

# %%
norm = stocks.div(stocks.iloc[0]) * 100

# %%
norm.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)

# %% [markdown]
# ### Creating a Price-weighted Index

# %%
stocks.head()
# Out:
#                   AMZN          BA        DIS         IBM         KO  \
# Date
# 2014-01-02  397.970001  136.669998  76.269997  185.529999  40.660000
# 2014-01-03  396.440002  137.619995  76.110001  186.639999  40.459999
# 2014-01-06  393.630005  138.410004  75.820000  186.000000  40.270000
# 2014-01-07  398.029999  140.509995  76.339996  189.710007  40.389999
# 2014-01-08  401.920013  140.820007  75.220001  187.970001  39.939999
#
#                  MSFT
# Date
# 2014-01-02  37.160000
# 2014-01-03  36.910000
# 2014-01-06  36.130001
# 2014-01-07  36.410000
# 2014-01-08  35.759998

# %%
norm.head()
# Out:
#                   AMZN          BA         DIS         IBM          KO  \
# Date
# 2014-01-02  100.000000  100.000000  100.000000  100.000000  100.000000
# 2014-01-03   99.615549  100.695103   99.790224  100.598286   99.508114
# 2014-01-06   98.909466  101.273144   99.409995  100.253329   99.040828
# 2014-01-07  100.015076  102.809685  100.091779  102.253009   99.335956
# 2014-01-08  100.992540  103.036518   98.623318  101.315153   98.229215
#
#                   MSFT
# Date
# 2014-01-02  100.000000
# 2014-01-03   99.327234
# 2014-01-06   97.228206
# 2014-01-07   97.981701
# 2014-01-08   96.232504

# %%
stocks.sum(axis=1)
# Out:
# Date
# 2014-01-02     874.259995
# 2014-01-03     874.179996
# 2014-01-06     870.260010
# 2014-01-07     881.389996
# 2014-01-08     881.630020
#                  ...
# 2018-12-21    2042.959946
# 2018-12-24    1986.129959
# 2018-12-26    2149.550014
# 2018-12-27    2147.790024
# 2018-12-28    2162.320026
# Length: 1257, dtype: float64

# %%
stocks.sum(axis=1).div(stocks.sum(axis=1)[0]).mul(100)
# Out:
# Date
# 2014-01-02    100.000000
# 2014-01-03     99.990850
# 2014-01-06     99.542472
# 2014-01-07    100.815547
# 2014-01-08    100.843002
#                  ...
# 2018-12-21    233.678764
# 2018-12-24    227.178410
# 2018-12-26    245.870797
# 2018-12-27    245.669485
# 2018-12-28    247.331462
# Length: 1257, dtype: float64

# %%
norm["PWI"] = stocks.sum(axis=1).div(stocks.sum(axis=1)[0]).mul(100)

# %%
norm.head()
# Out:
#                   AMZN          BA         DIS         IBM          KO  \
# Date
# 2014-01-02  100.000000  100.000000  100.000000  100.000000  100.000000
# 2014-01-03   99.615549  100.695103   99.790224  100.598286   99.508114
# 2014-01-06   98.909466  101.273144   99.409995  100.253329   99.040828
# 2014-01-07  100.015076  102.809685  100.091779  102.253009   99.335956
# 2014-01-08  100.992540  103.036518   98.623318  101.315153   98.229215
#
#                   MSFT         PWI
# Date
# 2014-01-02  100.000000  100.000000
# 2014-01-03   99.327234   99.990850
# 2014-01-06   97.228206   99.542472
# 2014-01-07   97.981701  100.815547
# 2014-01-08   96.232504  100.843002

# %%
norm.plot(figsize=(15,8), fontsize=15)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
norm.loc[:, ["AMZN", "PWI"]].plot(figsize=(15,8), fontsize=13)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
norm.loc[:, ["KO", "PWI"]].plot(figsize=(15,8), fontsize=13)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stocks.div(stocks.sum(axis=1), axis="rows")
# Out:
#                 AMZN        BA       DIS       IBM        KO      MSFT
# Date
# 2014-01-02  0.455208  0.156326  0.087239  0.212214  0.046508  0.042505
# 2014-01-03  0.453499  0.157428  0.087064  0.213503  0.046283  0.042222
# 2014-01-06  0.452313  0.159044  0.087123  0.213729  0.046274  0.041516
# 2014-01-07  0.451594  0.159419  0.086613  0.215240  0.045825  0.041310
# 2014-01-08  0.455883  0.159727  0.085319  0.213207  0.045302  0.040561
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-21  0.674242  0.149073  0.051014  0.054304  0.023285  0.048082
# 2018-12-24  0.676673  0.148107  0.050525  0.054161  0.023140  0.047394
# 2018-12-26  0.684283  0.146045  0.049234  0.051820  0.021837  0.046782
# 2018-12-27  0.680532  0.147659  0.049595  0.052975  0.022130  0.047109
# 2018-12-28  0.683534  0.146315  0.049623  0.052273  0.021828  0.046427
#
# [1257 rows x 6 columns]

# %%
weights_PWI = stocks.div(stocks.sum(axis=1), axis="rows")

# %%
weights_PWI.plot(figsize=(15,8), fontsize=13)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Equal Weighted Index Creation

# %%
ret = stocks.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AMZN        BA       DIS       IBM        KO      MSFT
# Date
# 2014-01-03 -0.003845  0.006951 -0.002098  0.005983 -0.004919 -0.006728
# 2014-01-06 -0.007088  0.005741 -0.003810 -0.003429 -0.004696 -0.021132
# 2014-01-07  0.011178  0.015172  0.006858  0.019946  0.002980  0.007750
# 2014-01-08  0.009773  0.002206 -0.014671 -0.009172 -0.011141 -0.017852
# 2014-01-09 -0.002264  0.009303 -0.004254 -0.003139 -0.005258 -0.006432

# %%
ret["Mean_ret"] = ret.mean(axis=1)

# %%
ret.head()
# Out:
#                 AMZN        BA       DIS       IBM        KO      MSFT  \
# Date
# 2014-01-03 -0.003845  0.006951 -0.002098  0.005983 -0.004919 -0.006728
# 2014-01-06 -0.007088  0.005741 -0.003810 -0.003429 -0.004696 -0.021132
# 2014-01-07  0.011178  0.015172  0.006858  0.019946  0.002980  0.007750
# 2014-01-08  0.009773  0.002206 -0.014671 -0.009172 -0.011141 -0.017852
# 2014-01-09 -0.002264  0.009303 -0.004254 -0.003139 -0.005258 -0.006432
#
#             Mean_ret
# Date
# 2014-01-03 -0.000776
# 2014-01-06 -0.005736
# 2014-01-07  0.010647
# 2014-01-08 -0.006810
# 2014-01-09 -0.002007

# %%
ret.Mean_ret.add(1).cumprod().mul(100)
# Out:
# Date
# 2014-01-03     99.922418
# 2014-01-06     99.349275
# 2014-01-07    100.407087
# 2014-01-08     99.723361
# 2014-01-09     99.523181
#                  ...
# 2018-12-21    175.330386
# 2018-12-24    169.441552
# 2018-12-26    179.083168
# 2018-12-27    180.594646
# 2018-12-28    180.437838
# Name: Mean_ret, Length: 1256, dtype: float64

# %%
norm["EWI"] = 100

# %%
norm.iloc[1:, -1]=ret.Mean_ret.add(1).cumprod().mul(100)

# %%
norm
# Out:
#                   AMZN          BA         DIS         IBM          KO  \
# Date
# 2014-01-02  100.000000  100.000000  100.000000  100.000000  100.000000
# 2014-01-03   99.615549  100.695103   99.790224  100.598286   99.508114
# 2014-01-06   98.909466  101.273144   99.409995  100.253329   99.040828
# 2014-01-07  100.015076  102.809685  100.091779  102.253009   99.335956
# 2014-01-08  100.992540  103.036518   98.623318  101.315153   98.229215
# ...                ...         ...         ...         ...         ...
# 2018-12-21  346.119041  222.836022  136.646133   59.796261  116.994589
# 2018-12-24  337.703836  215.233780  131.572050   57.979842  113.034922
# 2018-12-26  369.600729  229.699273  138.757056   60.038808  115.445152
# 2018-12-27  367.273918  232.048013  139.661730   61.327009  116.896210
# 2018-12-28  371.389807  231.491922  140.684421   60.922762  116.084606
#
#                   MSFT         PWI         EWI
# Date
# 2014-01-02  100.000000  100.000000  100.000000
# 2014-01-03   99.327234   99.922418   99.922418
# 2014-01-06   97.228206   99.349275   99.349275
# 2014-01-07   97.981701  100.407087  100.407087
# 2014-01-08   96.232504   99.723361   99.723361
# ...                ...         ...         ...
# 2018-12-21  264.343390  175.330386  175.330386
# 2018-12-24  253.310004  169.441552  169.441552
# 2018-12-26  270.613558  179.083168  179.083168
# 2018-12-27  272.282026  180.594646  180.594646
# 2018-12-28  270.156081  180.437838  180.437838
#
# [1257 rows x 8 columns]

# %%
norm.iloc[:, [0,1,2,3,4,5,7]].plot(figsize=(15,8), fontsize=13)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
norm.loc[:, ["AMZN", "EWI"]].plot(figsize=(15,8), fontsize=13)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
norm.iloc[:, -2:].plot(figsize=(15,8), fontsize=13)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
weights_EWI = stocks.copy()

# %%
weights_EWI.iloc[:,:] = (1/6)

# %%
weights_EWI
# Out:
#                 AMZN        BA       DIS       IBM        KO      MSFT
# Date
# 2014-01-02  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2014-01-03  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2014-01-06  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2014-01-07  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2014-01-08  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# ...              ...       ...       ...       ...       ...       ...
# 2018-12-21  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2018-12-24  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2018-12-26  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2018-12-27  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
# 2018-12-28  0.166667  0.166667  0.166667  0.166667  0.166667  0.166667
#
# [1257 rows x 6 columns]

# %%
weights_EWI.plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)

# %% [markdown]
# ### Value Weighted Index Creation

# %%
listings = pd.read_csv("data/listings_clean.csv")

# %%
listings.head()
# Out:
#   Symbol Exchange                           Name  Last_Price    Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68  2.593470e+10
# 1     AA     NYSE              Alcoa Corporation       29.15  5.407810e+09
# 2   AABA   NASDAQ                    Altaba Inc.       75.39  4.278113e+10
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16  5.314109e+07
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02  1.527687e+10
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %%
listings.tail()
# Out:
#      Symbol Exchange                           Name  Last_Price    Market_Cap  \
# 6847   ZUMZ   NASDAQ                    Zumiez Inc.       26.72  6.819191e+08
# 6848    ZUO     NYSE                    Zuora, Inc.       19.79  2.147266e+09
# 6849   ZYME     NYSE                 Zymeworks Inc.       15.74  5.040782e+08
# 6850   ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85  1.653995e+08
# 6851   ZYXI   NASDAQ                    Zynex, Inc.        5.02  1.618349e+08
#
#       IPO_Year             Sector  \
# 6847      2005  Consumer Services
# 6848      2018         Technology
# 6849      2017        Health Care
# 6850      2015        Health Care
# 6851      1969        Health Care
#
#                                                Industry
# 6847                     Clothing/Shoe/Accessory Stores
# 6848            Computer Software: Prepackaged Software
# 6849                              Major Pharmaceuticals
# 6850                              Major Pharmaceuticals
# 6851  Biotechnology: Electromedical & Electrotherape...

# %%
listings.set_index("Symbol", inplace=True)

# %%
ticker=["AMZN", "BA", "DIS", "IBM", "KO", "MSFT"]
